# %%
import pandas as pd

# %%
base = pd.read_csv("DADOS/insect.csv")
base.head()
# Out:
#    count spray
# 0     10     A
# 1      7     A
# 2     20     A
# 3     14     A
# 4     14     A

# %%
agrupado = base.groupby(["spray"])["count"].sum()
agrupado
# Out:
# spray
# A    174
# B    184
# C     25
# D     59
# E     42
# F    200
# Name: count, dtype: int64

# %%
agrupado.plot.bar()
# Out:
# <Axes: xlabel='spray'>

# %%
agrupado.plot.bar(color = ["blue","green","pink","black","yellow","orange"])
# Out:
# <Axes: xlabel='spray'>

# %%
agrupado.plot.pie()
# Out:
# <Axes: ylabel='count'>

# %%
agrupado.plot.pie(legend=True)
# Out:
# <Axes: ylabel='count'>
