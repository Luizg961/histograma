# %%
import pandas as pd
import seaborn as srn
import matplotlib.pyplot as plt

# %%
base = pd.read_csv("DADOS/chicken.csv")
base.head()
# Out:
#    weight       feed
# 0     179  horsebean
# 1     160  horsebean
# 2     136  horsebean
# 3     227  horsebean
# 4     217  horsebean

# %%
agrupado = base.groupby(["feed"])["weight"].sum()
agrupado
# Out:
# feed
# casein       3883
# horsebean    1602
# linseed      2625
# meatmeal     3046
# soybean      3450
# sunflower    3947
# Name: weight, dtype: int64

# %%
#FAZENDO O FILTRO TRAZENDO TODOS OS VALORES DE CASEIN

teste = base.loc[base["feed"] == "casein"]
teste
# Out:
#     weight    feed
# 59     368  casein
# 60     390  casein
# 61     379  casein
# 62     260  casein
# 63     404  casein
# 64     318  casein
# 65     352  casein
# 66     359  casein
# 67     216  casein
# 68     222  casein
# 69     283  casein
# 70     332  casein

# %%
#FAZER UM FILTRO PARA AS LINHAS DESEJADAS E COLUNAS

srn.kdeplot(base.loc[base["feed"]== "casein"].weight).set(title="casein")
# Out:
# [Text(0.5, 1.0, 'casein')]

# %%
srn.histplot(base.loc[base["feed"]=="horsebean"], kde=True).set(title="horsebean")
# Out:
# [Text(0.5, 1.0, 'horsebean')]

# %%
srn.histplot(base.loc[base["feed"] == "linseed"], kde=True).set(title="linseed")
# Out:
# [Text(0.5, 1.0, 'linseed')]

# %%
srn.histplot(base.loc[base["feed"] == "meatmeal"],kde=True).set(title="meatmeal")
# Out:
# [Text(0.5, 1.0, 'meatmeal')]

# %%
srn.histplot(base.loc[base["feed"] == "soybean"],kde=True).set(title="soybean")
# Out:
# [Text(0.5, 1.0, 'soybean')]

# %%
srn.histplot(base.loc[base["feed"] == "sunflower"], kde=True).set(title="sunflower")
# Out:
# [Text(0.5, 1.0, 'sunflower')]

# %%
plt.figure()
plt.subplot(3,2,1)
srn.histplot(base.loc[base["feed"] == "casein"],kde=True).set(title="casein")
plt.subplot(3,2,2)
srn.histplot(base.loc[base["feed"] == "horsebean"],kde=True).set(title="horsebean")
plt.subplot(3,2,3)
srn.histplot(base.loc[base["feed"] == "linseed"],kde=True).set(title="linseed")
plt.subplot(3,2,4)
srn.histplot(base.loc[base["feed"] == "meatmeal"],kde=True).set(title="meatmeal")
plt.subplot(3,2,5)
srn.histplot(base.loc[base["feed"] == "soybean"], kde=True).set(title="soybean")
plt.subplot(3,2,6)
srn.histplot(base.loc[base["feed"] == "sunflower"], kde =True).set(title="sunflower")

#AJUSTAR OS GRAFICOS
plt.tight_layout()
