# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
dados = pd.read_csv("DADOS/credit.csv")

dados.shape
# Out:
# (1000, 21)

# %%
dados.head(10)
# Out:
#   checking_status  duration                    credit_history  \
# 0              <0         6  'critical/other existing credit'
# 1        0<=X<200        48                   'existing paid'
# 2   'no checking'        12  'critical/other existing credit'
# 3              <0        42                   'existing paid'
# 4              <0        24              'delayed previously'
# 5   'no checking'        36                   'existing paid'
# 6   'no checking'        24                   'existing paid'
# 7        0<=X<200        36                   'existing paid'
# 8   'no checking'        12                   'existing paid'
# 9        0<=X<200        30  'critical/other existing credit'
#
#                purpose  credit_amount      savings_status  employment  \
# 0             radio/tv           1169  'no known savings'         >=7
# 1             radio/tv           5951                <100      1<=X<4
# 2            education           2096                <100      4<=X<7
# ...

# %%
#plt.hist(dados.iloc[:,7],bins = 10)
sns.histplot(dados.iloc[:,7],kde=True, bins = 10 ).set(title = "installment_commitment")
# Out:
# [Text(0.5, 1.0, 'installment_commitment')]

# %%
sns.kdeplot(dados.iloc[:,4]).set(title="CREDITO")
# Out:
# [Text(0.5, 1.0, 'CREDITO')]

# %%
plt.hist(dados.iloc[:,4], bins =100)
plt.title("CREDITO")
plt.ylabel("EMPRESTADO")
plt.xlabel("QUANTIDADE")
# Out:
# Text(0.5, 0, 'QUANTIDADE')

# %%
sns.kdeplot(dados.iloc[:,4]).set(title="CREDITO")
# Out:
# [Text(0.5, 1.0, 'CREDITO')]

# %%
dados.head()
# Out:
#   checking_status  duration                    credit_history  \
# 0              <0         6  'critical/other existing credit'
# 1        0<=X<200        48                   'existing paid'
# 2   'no checking'        12  'critical/other existing credit'
# 3              <0        42                   'existing paid'
# 4              <0        24              'delayed previously'
#
#                purpose  credit_amount      savings_status employment  \
# 0             radio/tv           1169  'no known savings'        >=7
# 1             radio/tv           5951                <100     1<=X<4
# 2            education           2096                <100     4<=X<7
# 3  furniture/equipment           7882                <100     4<=X<7
# 4            'new car'           4870                <100     1<=X<4
#
#    installment_commitment       personal_status other_parties  ...  \
# 0                       4         'male single'          none  ...
# ...

# %%
dados.tail(2)
# Out:
#     checking_status  duration                    credit_history     purpose  \
# 998              <0        45                   'existing paid'    radio/tv
# 999        0<=X<200        45  'critical/other existing credit'  'used car'
#
#      credit_amount savings_status  employment  installment_commitment  \
# 998           1845           <100      1<=X<4                       4
# 999           4576     100<=X<500  unemployed                       3
#
#     personal_status other_parties  ...   property_magnitude age  \
# 998   'male single'          none  ...  'no known property'  23
# 999   'male single'          none  ...                  car  27
#
#      other_payment_plans     housing existing_credits      job num_dependents  \
# 998                 none  'for free'                1  skilled              1
# 999                 none         own                1  skilled              1
#
#      own_telephone foreign_worker class
# 998            yes            yes   bad
# ...

# %%
dados[["duration"]]
# Out:
#      duration
# 0           6
# 1          48
# 2          12
# 3          42
# 4          24
# ..        ...
# 995        12
# 996        30
# 997        12
# 998        45
# 999        45
#
# [1000 rows x 1 columns]

# %%
plt.hist(dados.iloc[:,1], bins=10)
plt.title("DURAÇAO")
plt.ylabel("COUNT")
plt.xlabel("DURAÇAO")
# Out:
# Text(0.5, 0, 'DURAÇAO')

# %%
sns.histplot(dados.iloc[:,1], kde=True, bins=10).set(title="DURAÇAO")
# Out:
# [Text(0.5, 1.0, 'DURAÇAO')]

# %%
sns.kdeplot(dados.iloc[:,1]).set(title="DURAÇAO")
# Out:
# [Text(0.5, 1.0, 'DURAÇAO')]

# %%
sns.histplot(dados.iloc[:,1] , kde=False,bins=10).set(title="DURAÇAO")
# Out:
# [Text(0.5, 1.0, 'DURAÇAO')]

# %%
dados.loc[1:5]
# Out:
#   checking_status  duration                    credit_history  \
# 1        0<=X<200        48                   'existing paid'
# 2   'no checking'        12  'critical/other existing credit'
# 3              <0        42                   'existing paid'
# 4              <0        24              'delayed previously'
# 5   'no checking'        36                   'existing paid'
#
#                purpose  credit_amount      savings_status employment  \
# 1             radio/tv           5951                <100     1<=X<4
# 2            education           2096                <100     4<=X<7
# 3  furniture/equipment           7882                <100     4<=X<7
# 4            'new car'           4870                <100     1<=X<4
# 5            education           9055  'no known savings'     1<=X<4
#
#    installment_commitment       personal_status other_parties  ...  \
# 1                       2  'female div/dep/mar'          none  ...
# ...

# %%
plt.hist(dados.iloc[:,1], bins=10)
plt.title("DURAÇAO")
plt.ylabel("FREQUENCIA")
plt.xlabel("QUANTIDADE")
# Out:
# Text(0.5, 0, 'QUANTIDADE')

# %%
dados.loc[[3,5]]
# Out:
#   checking_status  duration   credit_history              purpose  \
# 3              <0        42  'existing paid'  furniture/equipment
# 5   'no checking'        36  'existing paid'            education
#
#    credit_amount      savings_status employment  installment_commitment  \
# 3           7882                <100     4<=X<7                       2
# 5           9055  'no known savings'     1<=X<4                       2
#
#   personal_status other_parties  ...   property_magnitude age  \
# 3   'male single'     guarantor  ...     'life insurance'  45
# 5   'male single'          none  ...  'no known property'  35
#
#    other_payment_plans     housing existing_credits                   job  \
# 3                 none  'for free'                1               skilled
# 5                 none  'for free'                1  'unskilled resident'
#
#   num_dependents  own_telephone foreign_worker class
# 3              2           none            yes  good
# ...

# %%
dados.loc[dados["purpose"] == "radio/tv"]
# Out:
#     checking_status  duration                    credit_history   purpose  \
# 0                <0         6  'critical/other existing credit'  radio/tv
# 1          0<=X<200        48                   'existing paid'  radio/tv
# 8     'no checking'        12                   'existing paid'  radio/tv
# 12         0<=X<200        12                   'existing paid'  radio/tv
# 15               <0        24                   'existing paid'  radio/tv
# ..              ...       ...                               ...       ...
# 989        0<=X<200        24  'critical/other existing credit'  radio/tv
# 991   'no checking'        15                        'all paid'  radio/tv
# 992              <0        18                   'existing paid'  radio/tv
# 997   'no checking'        12                   'existing paid'  radio/tv
# 998              <0        45                   'existing paid'  radio/tv
#
#      credit_amount      savings_status employment  installment_commitment  \
# ...

# %%
dados.loc[dados["credit_amount"] >18000]

sns.histplot(dados.iloc[:,4], kde=False, bins=10).set(title="CREDITO AMOUNT")
# Out:
# [Text(0.5, 1.0, 'CREDITO AMOUNT')]

# %%
plt.hist(dados.iloc[:,4], bins=10)
plt.title("CREDITO")
plt.ylabel("COUNT")
plt.xlabel("CREDIT AMOUNT")
# Out:
# Text(0.5, 0, 'CREDIT AMOUNT')

# %%
sns.histplot(dados.iloc[:,4],kde=True,bins=10).set(title="CREDITO")
# Out:
# [Text(0.5, 1.0, 'CREDITO')]

# %%
sns.kdeplot(dados.iloc[:,4]).set(title="CREDITO")
# Out:
# [Text(0.5, 1.0, 'CREDITO')]

# %%
credito2 = dados.loc[dados["credit_amount"] > 18000]
print(credito2)
# Out:
#     checking_status  duration         credit_history purpose  credit_amount  \
# 915        0<=X<200        48  'no credits/all paid'   other          18424
#
#     savings_status employment  installment_commitment       personal_status  \
# 915           <100     1<=X<4                       1  'female div/dep/mar'
#
#     other_parties  ...  property_magnitude age  other_payment_plans housing  \
# 915          none  ...    'life insurance'  32                 bank     own
#
#     existing_credits                          job num_dependents  \
# 915                1  'high qualif/self emp/mgmt'              1
#
#      own_telephone foreign_worker class
# 915            yes             no   bad
#
# [1 rows x 21 columns]

# %%
credito3 = dados[["checking_status", "duration"]].loc[dados["credit_amount"] >18000]

print(credito3)
# Out:
#     checking_status  duration
# 915        0<=X<200        48

# %%
si = pd.Series([2,1,5,4,89,63,4,6])
print(si)
# Out:
# 0     2
# 1     1
# 2     5
# 3     4
# 4    89
# 5    63
# 6     4
# 7     6
# dtype: int64

# %%
import numpy as np

array1 = np.array([2,1,5,4,89,63,4,6])
s2 = pd.Series(array1)
print(s2)
# Out:
# 0     2
# 1     1
# 2     5
# 3     4
# 4    89
# 5    63
# 6     4
# 7     6
# dtype: int32

# %%
s3 = dados["purpose"]
print(s3)
type(s3)
# Out:
# 0                 radio/tv
# 1                 radio/tv
# 2                education
# 3      furniture/equipment
# 4                'new car'
#               ...
# 995    furniture/equipment
# 996             'used car'
# 997               radio/tv
# 998               radio/tv
# 999             'used car'
# Name: purpose, Length: 1000, dtype: object
# pandas.core.series.Series

# %%
d4 = dados[["purpose"]]
type(d4)
# Out:
# pandas.core.frame.DataFrame

# %%
dados.rename(columns = {"duration":"duracao", "purpose:":"proposito"},inplace=True)

# %%
dados.head(1)
# Out:
#    duracao                    credit_history   purpose  credit_amount  \
# 0        6  'critical/other existing credit'  radio/tv           1169
#
#        savings_status employment  installment_commitment personal_status  \
# 0  'no known savings'        >=7                       4   'male single'
#
#   other_parties  residence_since property_magnitude  age other_payment_plans  \
# 0          none                4      'real estate'   67                none
#
#   housing  existing_credits      job  num_dependents own_telephone  \
# 0     own                 2  skilled               1           yes
#
#   foreign_worker class
# 0            yes  good

# %%
dados.drop("job" ,axis=1,  inplace=True)

print(dados)
# Out:
#      duracao                    credit_history              purpose  \
# 0          6  'critical/other existing credit'             radio/tv
# 1         48                   'existing paid'             radio/tv
# 2         12  'critical/other existing credit'            education
# 3         42                   'existing paid'  furniture/equipment
# 4         24              'delayed previously'            'new car'
# ..       ...                               ...                  ...
# 995       12                   'existing paid'  furniture/equipment
# 996       30                   'existing paid'           'used car'
# 997       12                   'existing paid'             radio/tv
# 998       45                   'existing paid'             radio/tv
# 999       45  'critical/other existing credit'           'used car'
#
#      credit_amount      savings_status  employment  installment_commitment  \
# ...

# %%
dados.head()
# Out:
#    duracao                    credit_history              purpose  \
# 0        6  'critical/other existing credit'             radio/tv
# 1       48                   'existing paid'             radio/tv
# 2       12  'critical/other existing credit'            education
# 3       42                   'existing paid'  furniture/equipment
# 4       24              'delayed previously'            'new car'
#
#    credit_amount      savings_status employment  installment_commitment  \
# 0           1169  'no known savings'        >=7                       4
# 1           5951                <100     1<=X<4                       2
# 2           2096                <100     4<=X<7                       2
# 3           7882                <100     4<=X<7                       2
# 4           4870                <100     1<=X<4                       3
#
#         personal_status other_parties  residence_since   property_magnitude  \
# ...

# %%
dados.isnull()
# Out:
#      duracao  credit_history  purpose  credit_amount  savings_status  \
# 0      False           False    False          False           False
# 1      False           False    False          False           False
# 2      False           False    False          False           False
# 3      False           False    False          False           False
# 4      False           False    False          False           False
# ..       ...             ...      ...            ...             ...
# 995    False           False    False          False           False
# 996    False           False    False          False           False
# 997    False           False    False          False           False
# 998    False           False    False          False           False
# 999    False           False    False          False           False
#
#      employment  installment_commitment  personal_status  other_parties  \
# ...

# %%
dados.isnull().sum()
# Out:
# duracao                   0
# credit_history            0
# purpose                   0
# credit_amount             0
# savings_status            0
# employment                0
# installment_commitment    0
# personal_status           0
# other_parties             0
# residence_since           0
# property_magnitude        0
# age                       0
# other_payment_plans       0
# housing                   0
# existing_credits          0
# num_dependents            0
# own_telephone             0
# foreign_worker            0
# class                     0
# dtype: int64

# %%
dados["duracao"].fillna(0,inplace = True)
# Out:
# C:\Users\gustavo\AppData\Local\Temp\ipykernel_14436\2172241644.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   dados["duracao"].fillna(0,inplace = True)

# %%
dados.iloc[0:3,0:5]
# Out:
#    duracao                    credit_history    purpose  credit_amount  \
# 0        6  'critical/other existing credit'   radio/tv           1169
# 1       48                   'existing paid'   radio/tv           5951
# 2       12  'critical/other existing credit'  education           2096
#
#        savings_status
# 0  'no known savings'
# 1                <100
# 2                <100

# %%
dados.iloc[[0,1,2,3,7],0:5]
# Out:
#    duracao                    credit_history              purpose  \
# 0        6  'critical/other existing credit'             radio/tv
# 1       48                   'existing paid'             radio/tv
# 2       12  'critical/other existing credit'            education
# 3       42                   'existing paid'  furniture/equipment
# 7       36                   'existing paid'           'used car'
#
#    credit_amount      savings_status
# 0           1169  'no known savings'
# 1           5951                <100
# 2           2096                <100
# 3           7882                <100
# 7           6948                <100
