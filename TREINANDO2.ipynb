# %%
import pandas as pd 
import matplotlib.pyplot as plt
import seaborn as sns

# %%
base = pd.read_csv("DADOS/trees.csv")
base.head()
# Out:
#    Girth  Height  Volume
# 0    8.3      70    10.3
# 1    8.6      65    10.3
# 2    8.8      63    10.2
# 3   10.5      72    16.4
# 4   10.7      81    18.8

# %%
plt.hist(base.iloc[:,1],bins=10)
plt.title("ARVORES")
plt.ylabel("CIRCUFERENCIA")
plt.xlabel("VULOME")

"""
plt.hist(base.iolc[:,1], bins=10)
plt.title("ARVORES")
plt.xlabel("CIRCUFERENCIA")
plt.label("VOLUME")

--------------------
plt.hist(base.iloc[:,1],bins=10)
plt.title("ARVORES")
plt.ylabel("CIRCUFERENCIA")
plt.xlabel("VOLUME")
"""
# Out:
# '\nplt.hist(base.iolc[:,1], bins=10)\nplt.title("ARVORES")\nplt.xlabel("CIRCUFERENCIA")\nplt.label("VOLUME")\n'

# %%
#sns.histplot(base.iloc[:,1], kde=False,bins= 6 ).set(title="ARVORES")
sns.histplot(base.iloc[:,1], kde =False, bins= 6 ).set(title="ARVORES")
"""

sns.histplot(base.iloc[:,1], kde=False, bins=6).set(title="ARVORES")
sns.histplot(base.iloc[:,1], kde=False, bins=6).set(title="ARVORES")
sns.histplot(base.iloc[:,1], kde=False, bins=6).set(title="ARVORES")
"""
# Out:
# '\n\nsns.histplot(base.iloc[:,1] , kde = False, bins=6).set(title="ARVORES")\n\n'

# %%
sns.histplot(base.iloc[:,1] ,kde=True, bins= 6 ).set(title="ARVORES")

"""
sns.histplot(base.iloc[:,1], kde=True, bins=6).set(title="ARVORES")

sns.histplot(base.iloc[:,1] , kde=True, bins=6).set(title="ARVORES")

sns.histplot(base.iloc[:,1] , kde=True, bins=6).set(title="ARVORES")
"""
# Out:
# [Text(0.5, 1.0, 'ARVORES')]

# %%
sns.kdeplot(base.iloc[:,1] ).set(title="ARVORE")

"""
sns.kdeplot(base.iloc[:,1]).set(title="ARVORES")
sns.kdeplot(base.iloc[:,1]).set(title="ARVORES")
sns.kdeplot(base.iloc[:,1]).set(title="ARVORES")

"""
# Out:
# [Text(0.5, 1.0, 'ARVORE')]

# %%
plt.scatter(x=base.Girth,y=base.Volume, marker="*" )
plt.title("ARVORES")
plt.xlabel("CIRCUFERENCIA")
plt.ylabel("VOLUME")

"""
plt.scatter(x=Girth,y=base.Volume, marker="*")
plt.title("ARVORES")
plt.ylabel("CIRCUFERENCIA")
plt.xlabel("VOLUME")


plt.scatter(x =base.Girth, y=base.Volume,marker="*")
plt.title("ARVORE")
plt.ylabel("VOLUME")
plt.xlabel("CIRCUFERENCIA")



plt.scatter(x=base.Girth, y=base.Volume, marker="*")
plt.title("ARVORES)
plt.ylabel("VOLUME)
plt.xlabel("CIRCUFERENCIa")
"""
# Out:
# Text(0, 0.5, 'VOLUME')

# %%
plt.plot(base.Girth,base.Volume)

"""
plt.plot(base.Girth, base.Volume)

plt.plot(base.Girth,y=base.Volume)

plt.plot(base.Girth,base.Volume)

"""

# %%
sns.regplot(x=base.Girth , y=base.Volume, data=base, x_jitter = 0.3, fit_reg=True)

"""
sns.regplot(x=base.Girth,y=base.Volume, data=base, x_jitter=0.3, fit_reg=True)

sns.regplot(x=base.Girth,y=base.Volume, data=base, x_jitter=0.3, fit_reg=True)

sns.regplot(x=base.Girth,y=base.Volume, data=base, x_jitter=0.3 fit_reg=True)

sns.regplot(x=base.Girth,y=base.Volume, data=base, x_jitter=0.3, fit_reg=True)

"""
# Out:
# <Axes: xlabel='Girth', ylabel='Volume'>

# %%
sns.regplot(x=base.Girth, y=base.Volume, data=base , x_jitter = 0.3, fit_reg=False)

"""
sns.regplot(x=base.Girth, y=base.Volume,data=base, x_jitter=0.3, fit_reg=False)
sns.regplot(x=base.Girth, y=base.Volume,data=base, x_jitter=0.3, fit_reg=False)
sns.regplot(x=base.Girth, y=base.Volume,data=base, x_jitter=0.3, fit_reg=False)
sns.regplot(x=base.Girth,y=base.volume, data=base, x_jitter=0.3, fit_reg=False)

"""
# Out:
# <Axes: xlabel='Girth', ylabel='Volume'>
